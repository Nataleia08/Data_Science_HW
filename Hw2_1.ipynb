# %%
import pandas as pd
# %matplotlib inline

# %%
#Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)"
tmp = pd.read_html("data.html", encoding ="utf-8")[0]
print(tmp)
# Out:
#                        регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1           Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2           Волинська область  247.0  250.0  179.0   153   150   137   125
# 3    Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4            Донецька область  271.0  214.0  140.0   109    94    82    70
# 5         Житомирська область  261.0  223.0  159.0   129   128   118   108
# 6        Закарпатська область  314.0  273.0  207.0   168   161   138   128
# 7          Запорізька область  219.0  197.0  150.0   124   107    92    81
# 8   Івано-Франківська область  243.0  248.0  182.0   155   144   131   122
# 9            Київська область  204.0  189.0  156.0   123   111    99    92
# 10     Кіровоградська область  216.0  171.0  145.0   126   119   107    96
# ...

# %%
#Вивести перші рядки таблиці за допомогою методу head
print(tmp.head())
# Out:
#                       регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0  Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1          Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2          Волинська область  247.0  250.0  179.0   153   150   137   125
# 3   Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4           Донецька область  271.0  214.0  140.0   109    94    82    70
#
#    2000  2004  2008  2012   2014
# 0    73    90   119   126    NaN
# 1    84    90   108   112  109.0
# 2   112   119   148   148  141.0
# 3    71    89   110   112  111.0
# 4    61    76    98    98   82.0

# %%
#Визначте кількість рядків та стовпців у датафреймі (атрибут shape)
print(tmp.shape)
# Out:
# (28, 13)

# %%
#Замініть у таблиці значення "—" на значення NaN
tmp.replace("-", None)
print(tmp)
# Out:
#                        регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1           Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2           Волинська область  247.0  250.0  179.0   153   150   137   125
# 3    Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4            Донецька область  271.0  214.0  140.0   109    94    82    70
# 5         Житомирська область  261.0  223.0  159.0   129   128   118   108
# 6        Закарпатська область  314.0  273.0  207.0   168   161   138   128
# 7          Запорізька область  219.0  197.0  150.0   124   107    92    81
# 8   Івано-Франківська область  243.0  248.0  182.0   155   144   131   122
# 9            Київська область  204.0  189.0  156.0   123   111    99    92
# 10     Кіровоградська область  216.0  171.0  145.0   126   119   107    96
# ...

# %%
#Визначте типи всіх стовпців за допомогою dataframe.dtypes
print(tmp.dtypes)
# Out:
# регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 1992        int64
# 1994        int64
# 1996        int64
# 2000        int64
# 2004        int64
# 2008        int64
# 2012        int64
# 2014      float64
# dtype: object

# %%
from numpy import int64
#Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"
pd.to_numeric(tmp["1950"])
pd.to_numeric(tmp["1960"])
pd.to_numeric(tmp["1970"])
pd.to_numeric(tmp["2014"])

print(tmp.dtypes)
# Out:
# регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 1992        int64
# 1994        int64
# 1996        int64
# 2000        int64
# 2004        int64
# 2008        int64
# 2012        int64
# 2014      float64
# dtype: object

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
num_nan = tmp.isna().sum(min_count=True)
print(num_nan)
# Out:
# регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 1992      0
# 1994      0
# 1996      0
# 2000      0
# 2004      0
# 2008      0
# 2012      0
# 2014      2
# dtype: int64

# %%
#Видаліть з таблиці дані по всій країні, останній рядок таблиці
tmp = tmp.drop([27])
print(tmp)
# Out:
#                        регіон   1950   1960   1970  1990  1992  1994  1996  \
# 0   Автономна Республіка Крим  230.0  206.0  160.0   130   109    93    80
# 1           Вінницька область  224.0  192.0  142.0   124   119   107   103
# 2           Волинська область  247.0  250.0  179.0   153   150   137   125
# 3    Дніпропетровська область  204.0  204.0  151.0   123   106    92    80
# 4            Донецька область  271.0  214.0  140.0   109    94    82    70
# 5         Житомирська область  261.0  223.0  159.0   129   128   118   108
# 6        Закарпатська область  314.0  273.0  207.0   168   161   138   128
# 7          Запорізька область  219.0  197.0  150.0   124   107    92    81
# 8   Івано-Франківська область  243.0  248.0  182.0   155   144   131   122
# 9            Київська область  204.0  189.0  156.0   123   111    99    92
# 10     Кіровоградська область  216.0  171.0  145.0   126   119   107    96
# ...

# %%
#Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)
tmp = tmp.fillna({"1950": tmp["1950"].mean(), "1960": tmp["1960"].mean(), "1970": tmp["1970"].mean(), "2014": tmp["2014"].mean()})
print(tmp)
# Out:
#                        регіон    1950        1960   1970  1990  1992  1994  \
# 0   Автономна Республіка Крим  230.00  206.000000  160.0   130   109    93
# 1           Вінницька область  224.00  192.000000  142.0   124   119   107
# 2           Волинська область  247.00  250.000000  179.0   153   150   137
# 3    Дніпропетровська область  204.00  204.000000  151.0   123   106    92
# 4            Донецька область  271.00  214.000000  140.0   109    94    82
# 5         Житомирська область  261.00  223.000000  159.0   129   128   118
# 6        Закарпатська область  314.00  273.000000  207.0   168   161   138
# 7          Запорізька область  219.00  197.000000  150.0   124   107    92
# 8   Івано-Франківська область  243.00  248.000000  182.0   155   144   131
# 9            Київська область  204.00  189.000000  156.0   123   111    99
# 10     Кіровоградська область  216.00  171.000000  145.0   126   119   107
# ...

# %%
#Отримайте список регіонів, де рівень народжуваності у 2014(9?) році був вищим за середній по Україні
ser = tmp["2014"].mean()
print(ser)
tmp1 = tmp[tmp["2014"]>tmp["2014"].mean()]["регіон"]
print(tmp1)
# Out:
# 111.44
# 2             Волинська область
# 5           Житомирська область
# 6          Закарпатська область
# 8     Івано-Франківська область
# 9              Київська область
# 12            Львівська область
# 13         Миколаївська область
# 14              Одеська область
# 16           Рівненська область
# 20           Херсонська область
# 21          Хмельницька область
# 23          Чернівецька область
# 25                         Київ
# Name: регіон, dtype: object

# %%
#У якому регіоні була найвища народжуваність у 2014 році?
tmp2 = tmp.sort_values(by="регіон").reset_index(drop = True)
print(tmp2["регіон"].iloc[26])
# Out:
# Чернігівська область

# %%
#Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році
tmp["2014"].plot(kind='bar', grid=True, title="Народжуваність в 2014 році по регіонам", legend = True, color = "pink")
plt.xticks(np.arange(0,27), tmp["регіон"], rotation=90)
plt.legend()
plt.grid()
plt.show()

# %%
#додайте від 3 до 5 графіків функцій різного типу на ваш вибір. Задайте графікам оформлення, щоб кожен графік у своїй домашній роботі чимось відрізнявся і не був схожим на інші. Можна використовувати як matplotlib, так і seaborn.
import matplotlib.pyplot as plt
import numpy as np
tmp["2012"].plot(kind = 'barh', color = "#00BFFF")
plt.yticks(np.arange(0,27), tmp["регіон"])
plt.title('Народжуваність по регіонам в 2012', fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axs = plt.subplots(1, 1, figsize=(10, 5))
axs.plot(tmp["регіон"], tmp["1950"], color = "yellow", label='1950')
axs.plot(tmp["регіон"], tmp["1960"], color = "blue", label='1960')
axs.plot(tmp["регіон"], tmp["1970"], color = "red", label='1970')
plt.xticks(np.arange(0,27), tmp["регіон"], rotation=90)
plt.title('Народжуваність по регіонам в 1950-1970', fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
gr11 = tmp.loc[25].drop(["регіон"])
gr11.plot(kind = 'line', linestyle="--", color="#00FF7F", linewidth=2, marker="X")
plt.title('Народжуваність в Києві по роках', fontsize=15)
plt.grid()
plt.show()
